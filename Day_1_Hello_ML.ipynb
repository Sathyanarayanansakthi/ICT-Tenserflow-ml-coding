# %%
import tensorflow as tf # This is the main library for building and training machine learning models.
import numpy as np
from tensorflow import keras #A high-level API within TensorFlow that simplifies the creation of neural networks.


model= keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs= np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys= np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=50)

a= np.array([10.0])
print(model.predict(a))
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 3.3065
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.7604
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.3276
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.9838
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.7102
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.4919
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.3171
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1766
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0633
# Epoch 10/500
# ...

# %%
b= np.array([5.0,6.0,7.0])
print(model.predict(b))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# [[ 8.995887]
#  [10.993721]
#  [12.991555]]

# %%
import tensorflow as tf # This is the main library for building and training machine learning models.
import numpy as np
from tensorflow import keras #A high-level API within TensorFlow that simplifies the creation of neural networks.

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('loss')<0.1):
            print("\nReached 90% accuracy so cancelling training!")
            self.model.stop_training = True

callbacks = myCallback()




model= keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs= np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys= np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=5000, callbacks=[callbacks])

a= np.array([10.0])
print(model.predict(a))
# Out:
# Epoch 1/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 2.6945
# Epoch 2/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 2.2723
# Epoch 3/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.9371
# Epoch 4/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.6702
# Epoch 5/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.4573
# Epoch 6/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.2868
# Epoch 7/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.1498
# Epoch 8/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.0392
# Epoch 9/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.9494
# Epoch 10/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.8761
# Epoch 11/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.8157
# Epoch 12/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.7656
# Epoch 13/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.7237
# Epoch 14/5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.6882
# ...
